# %% [markdown]
# <a href="https://colab.research.google.com/github/EDAttlee/Aloha_world/blob/main/Notebooks/Chap10/10_2_Convolution_for_MNIST_1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 10.2: Convolution for MNIST-1D**
#
# This notebook investigates a 1D convolutional network for MNIST-1D as in figure 10.7 and 10.8a.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-vba9b1ox
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-vba9b1ox
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.1.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14664 sha256=573f740ab7060ea149a6f2fb95fb45de80677033b29d29c6079f9fd91f312b4a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hfp0kxoc/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10

# TODO Create a model with the following layers
# 1. Convolutional layer, (input=length 40 and 1 channel, kernel size 3, stride 2, padding="valid", 15 output channels )
# 2. ReLU
# 3. Convolutional layer, (input=length 19 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels )
# 4. ReLU
# 5. Convolutional layer, (input=length 9 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels)
# 6. ReLU
# 7. Flatten (converts 4x15) to length 60
# 8. Linear layer (input size = 60, output size = 10)
# References:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# NOTE THAT THE CONVOLUTIONAL LAYERS NEED TO TAKE THE NUMBER OF INPUT CHANNELS AS A PARAMETER
# AND NOT THE INPUT SIZE.

# Replace the following function:
model = nn.Sequential(
  nn.Conv1d(in_channels=1, out_channels=15, kernel_size=3, stride=2, padding='valid', padding_mode='zeros'),
  nn.ReLU(),
  nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding='valid', padding_mode='zeros'),
  nn.ReLU(),
  nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding='valid', padding_mode='zeros'),
  nn.ReLU(),
  nn.Flatten(),
  nn.Linear(60, 10),
)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch[:,None,:])
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='validation')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('Part I: Validation Result %3.2f'%(errors_val[-1]))
ax.legend()
plt.show()
# Out:
# Epoch     0, train loss 2.069551, train error 80.47,  val loss 2.074723, percent error 81.10
# Epoch     1, train loss 1.624604, train error 65.32,  val loss 1.649529, percent error 70.10
# Epoch     2, train loss 1.366490, train error 54.35,  val loss 1.386227, percent error 58.70
# Epoch     3, train loss 1.313945, train error 54.62,  val loss 1.327971, percent error 57.90
# Epoch     4, train loss 1.309921, train error 53.70,  val loss 1.324497, percent error 56.20
# Epoch     5, train loss 1.078886, train error 42.17,  val loss 1.095115, percent error 45.90
# Epoch     6, train loss 0.928199, train error 37.15,  val loss 0.942386, percent error 39.40
# Epoch     7, train loss 0.852278, train error 32.82,  val loss 0.891677, percent error 36.40
# Epoch     8, train loss 0.744362, train error 29.07,  val loss 0.807523, percent error 33.40
# Epoch     9, train loss 0.657910, train error 25.32,  val loss 0.718733, percent error 28.80
# Epoch    10, train loss 0.604000, train error 22.60,  val loss 0.659784, percent error 25.40
# Epoch    11, train loss 0.559662, train error 21.12,  val loss 0.621490, percent error 23.70
# Epoch    12, train loss 0.548016, train error 20.78,  val loss 0.620369, percent error 22.20
# Epoch    13, train loss 0.510302, train error 19.12,  val loss 0.614817, percent error 23.10
# Epoch    14, train loss 0.460700, train error 17.20,  val loss 0.580124, percent error 20.20
# Epoch    15, train loss 0.380095, train error 14.00,  val loss 0.478581, percent error 16.70
# Epoch    16, train loss 0.318800, train error 11.22,  val loss 0.442688, percent error 15.70
# Epoch    17, train loss 0.313962, train error 11.25,  val loss 0.467961, percent error 15.10
# Epoch    18, train loss 0.281257, train error 10.35,  val loss 0.422666, percent error 14.90
# Epoch    19, train loss 0.263746, train error 9.62,  val loss 0.454861, percent error 15.60
# Epoch    20, train loss 0.173253, train error 5.65,  val loss 0.338436, percent error 10.80
# Epoch    21, train loss 0.158899, train error 4.95,  val loss 0.320914, percent error 10.10
# Epoch    22, train loss 0.146812, train error 4.62,  val loss 0.320267, percent error 10.30
# Epoch    23, train loss 0.144777, train error 4.47,  val loss 0.333647, percent error 11.10
# Epoch    24, train loss 0.167890, train error 5.75,  val loss 0.372093, percent error 11.30
# Epoch    25, train loss 0.140958, train error 4.40,  val loss 0.331446, percent error 11.30
# Epoch    26, train loss 0.121132, train error 3.97,  val loss 0.326706, percent error 10.60
# Epoch    27, train loss 0.125814, train error 4.45,  val loss 0.348366, percent error 10.20
# Epoch    28, train loss 0.117682, train error 3.68,  val loss 0.343011, percent error 10.30
# Epoch    29, train loss 0.096911, train error 2.72,  val loss 0.316195, percent error 10.60
# Epoch    30, train loss 0.100765, train error 2.88,  val loss 0.330857, percent error 10.00
# Epoch    31, train loss 0.096061, train error 3.10,  val loss 0.328067, percent error 9.50
# Epoch    32, train loss 0.093260, train error 2.80,  val loss 0.345256, percent error 10.20
# Epoch    33, train loss 0.104189, train error 3.35,  val loss 0.352478, percent error 10.40
# Epoch    34, train loss 0.079789, train error 2.22,  val loss 0.346831, percent error 9.90
# Epoch    35, train loss 0.074867, train error 2.18,  val loss 0.356132, percent error 10.80
# Epoch    36, train loss 0.079784, train error 2.30,  val loss 0.359974, percent error 10.70
# Epoch    37, train loss 0.073308, train error 2.35,  val loss 0.359959, percent error 10.00
# Epoch    38, train loss 0.069695, train error 2.05,  val loss 0.366180, percent error 9.60
# Epoch    39, train loss 0.062207, train error 1.85,  val loss 0.354566, percent error 9.60
# Epoch    40, train loss 0.055768, train error 1.45,  val loss 0.362451, percent error 9.50
# Epoch    41, train loss 0.052616, train error 1.30,  val loss 0.357221, percent error 9.90
# Epoch    42, train loss 0.053172, train error 1.53,  val loss 0.362204, percent error 9.60
# Epoch    43, train loss 0.050495, train error 1.18,  val loss 0.364100, percent error 9.70
# Epoch    44, train loss 0.048987, train error 1.35,  val loss 0.370336, percent error 9.70
# Epoch    45, train loss 0.046573, train error 1.07,  val loss 0.370487, percent error 9.50
# Epoch    46, train loss 0.046149, train error 1.10,  val loss 0.373876, percent error 9.10
# Epoch    47, train loss 0.047373, train error 1.35,  val loss 0.375174, percent error 9.20
# Epoch    48, train loss 0.043695, train error 1.05,  val loss 0.372352, percent error 9.50
# Epoch    49, train loss 0.041277, train error 0.88,  val loss 0.368851, percent error 9.00
# Epoch    50, train loss 0.043240, train error 0.90,  val loss 0.383457, percent error 9.60
# Epoch    51, train loss 0.043234, train error 0.88,  val loss 0.390837, percent error 9.30
# Epoch    52, train loss 0.039145, train error 0.85,  val loss 0.376052, percent error 9.50
# Epoch    53, train loss 0.038182, train error 0.78,  val loss 0.385493, percent error 9.40
# Epoch    54, train loss 0.038760, train error 0.75,  val loss 0.391132, percent error 9.10
# Epoch    55, train loss 0.039102, train error 0.93,  val loss 0.393981, percent error 9.40
# Epoch    56, train loss 0.036668, train error 0.72,  val loss 0.398416, percent error 9.50
# Epoch    57, train loss 0.036428, train error 0.72,  val loss 0.404519, percent error 9.40
# Epoch    58, train loss 0.033217, train error 0.62,  val loss 0.384957, percent error 9.70
# Epoch    59, train loss 0.033750, train error 0.57,  val loss 0.405642, percent error 9.90
# Epoch    60, train loss 0.031144, train error 0.47,  val loss 0.397845, percent error 9.50
# Epoch    61, train loss 0.030656, train error 0.35,  val loss 0.400968, percent error 9.50
# Epoch    62, train loss 0.031613, train error 0.60,  val loss 0.397245, percent error 9.80
# Epoch    63, train loss 0.031178, train error 0.43,  val loss 0.401477, percent error 9.50
# Epoch    64, train loss 0.030319, train error 0.57,  val loss 0.399606, percent error 9.80
# Epoch    65, train loss 0.029836, train error 0.47,  val loss 0.403067, percent error 9.50
# Epoch    66, train loss 0.029286, train error 0.38,  val loss 0.402445, percent error 9.40
# Epoch    67, train loss 0.028569, train error 0.32,  val loss 0.401810, percent error 9.40
# Epoch    68, train loss 0.028384, train error 0.38,  val loss 0.405799, percent error 9.70
# Epoch    69, train loss 0.029275, train error 0.45,  val loss 0.404400, percent error 9.80
# Epoch    70, train loss 0.027886, train error 0.32,  val loss 0.406959, percent error 9.50
# Epoch    71, train loss 0.027665, train error 0.30,  val loss 0.407432, percent error 9.50
# Epoch    72, train loss 0.026906, train error 0.28,  val loss 0.410679, percent error 9.40
# Epoch    73, train loss 0.029035, train error 0.38,  val loss 0.414125, percent error 10.20
# Epoch    74, train loss 0.026397, train error 0.28,  val loss 0.413447, percent error 9.50
# Epoch    75, train loss 0.026256, train error 0.25,  val loss 0.410483, percent error 9.70
# Epoch    76, train loss 0.026047, train error 0.25,  val loss 0.416266, percent error 9.70
# Epoch    77, train loss 0.025980, train error 0.30,  val loss 0.414908, percent error 10.00
# Epoch    78, train loss 0.025261, train error 0.20,  val loss 0.419747, percent error 9.50
# Epoch    79, train loss 0.025625, train error 0.30,  val loss 0.416207, percent error 9.70
# Epoch    80, train loss 0.025081, train error 0.20,  val loss 0.418088, percent error 9.40
# Epoch    81, train loss 0.024705, train error 0.28,  val loss 0.415494, percent error 9.40
# Epoch    82, train loss 0.024456, train error 0.20,  val loss 0.419071, percent error 9.40
# Epoch    83, train loss 0.024342, train error 0.15,  val loss 0.419896, percent error 9.40
# Epoch    84, train loss 0.024532, train error 0.22,  val loss 0.419064, percent error 9.60
# Epoch    85, train loss 0.023962, train error 0.18,  val loss 0.420608, percent error 9.40
# Epoch    86, train loss 0.023888, train error 0.12,  val loss 0.420966, percent error 9.50
# Epoch    87, train loss 0.024164, train error 0.18,  val loss 0.423284, percent error 9.40
# Epoch    88, train loss 0.023593, train error 0.15,  val loss 0.420975, percent error 9.40
# Epoch    89, train loss 0.023507, train error 0.15,  val loss 0.423874, percent error 9.40
# Epoch    90, train loss 0.023545, train error 0.22,  val loss 0.422615, percent error 9.40
# Epoch    91, train loss 0.023288, train error 0.15,  val loss 0.425280, percent error 9.40
# Epoch    92, train loss 0.023235, train error 0.15,  val loss 0.424489, percent error 9.30
# Epoch    93, train loss 0.023102, train error 0.12,  val loss 0.426863, percent error 9.50
# Epoch    94, train loss 0.022893, train error 0.10,  val loss 0.426953, percent error 9.40
# Epoch    95, train loss 0.022978, train error 0.12,  val loss 0.427825, percent error 9.60
# Epoch    96, train loss 0.023329, train error 0.18,  val loss 0.429140, percent error 9.20
# Epoch    97, train loss 0.023358, train error 0.18,  val loss 0.430335, percent error 9.10
# Epoch    98, train loss 0.022631, train error 0.12,  val loss 0.429529, percent error 9.30
# Epoch    99, train loss 0.022535, train error 0.18,  val loss 0.428962, percent error 9.50
